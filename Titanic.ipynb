# %%
# linear algebra
import numpy as np 

# data processing
import pandas as pd 

# data visualization
import seaborn as sns
# %matplotlib inline
from matplotlib import pyplot as plt
from matplotlib import style

# Algorithms
from sklearn import linear_model
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC, LinearSVC
from sklearn.naive_bayes import GaussianNB

# %%
eda = pd.read_csv(r"C:\Users\Enter\Desktop\PassengerId-200611-000941.csv")
eda.shape
# Out:
# (1142, 12)

# %%
eda.head(15)
# Out:
#     PassengerId   Survived   Pclass                             Name   \
# 0            1.0        0.0      3.0         Braund, Mr. Owen Harris
# 1            NaN        NaN      NaN       Cumings, Mrs. John Bradley
# 2            2.0        1.0      1.0        (Florence Briggs Thayer)
# 3            NaN        NaN      NaN                              NaN
# 4            3.0        1.0      3.0          Heikkinen, Miss. Laina
# 5            NaN        NaN      NaN     Futrelle, Mrs. Jacques Heath
# 6            4.0        1.0      1.0                 (Lily May Peel)
# 7            5.0        0.0      3.0        Allen, Mr. William Henry
# 8            6.0        0.0      3.0                Moran, Mr. James
# 9            7.0        0.0      1.0         McCarthy, Mr. Timothy J
# 10           8.0        0.0      3.0  Palsson, Master. Gosta Leonard
# 11           NaN        NaN      NaN            Johnson, Mrs. Oscar W
# ...

# %% [markdown]
# ## Variable Identification

# %% [markdown]
# ##### Dependent Variable - Survived

# %% [markdown]
# ##### Independent Variable - PassengerID, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked

# %%
eda.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1142 entries, 0 to 1141
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   PassengerId   891 non-null    float64
#  1   Survived      891 non-null    float64
#  2   Pclass        891 non-null    float64
#  3   Name          1088 non-null   object
#  4   Sex           891 non-null    object
#  5   Age           714 non-null    float64
#  6   SibSp         891 non-null    float64
#  7   Parch         891 non-null    float64
#  8   Ticket        926 non-null    object
#  9   Fare          891 non-null    float64
#  10  Cabin         234 non-null    object
#  11  Embarked      889 non-null    object
# dtypes: float64(7), object(5)
# memory usage: 107.2+ KB

# %% [markdown]
# ### Data Type

# %% [markdown]
# ##### String - Name, Sex, Ticket, Cabin, Embarked

# %% [markdown]
# ##### Numaric - PassengerId, Survived, Pclass, Age, SIbSp, Parch, Fare

# %% [markdown]
# ### Variable Category

# %% [markdown]
# ##### Caragorical Variable - Sex, Ticket, Cabin, Embarked

# %% [markdown]
# ##### Continous Variable - Age, PassengerID, Fare

# %% [markdown]
# ##### Discrete Variable - Survived, Pclass, SibSp, Parch

# %%
eda.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp   \
# count    891.000000  891.000000  891.000000  714.000000  891.000000
# mean     446.000000    0.383838    2.308642   29.699118    0.523008
# std      257.353842    0.486592    0.836071   14.526497    1.102743
# min        1.000000    0.000000    1.000000    0.420000    0.000000
# 25%      223.500000    0.000000    2.000000   20.125000    0.000000
# 50%      446.000000    0.000000    3.000000   28.000000    0.000000
# 75%      668.500000    1.000000    3.000000   38.000000    1.000000
# max      891.000000    1.000000    3.000000   80.000000    8.000000
#
#            Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
eda.columns
# Out:
# Index(['PassengerId ', 'Survived ', 'Pclass ', 'Name ', 'Sex ', 'Age ',
#        'SibSp ', 'Parch ', 'Ticket ', 'Fare ', 'Cabin ', 'Embarked '],
#       dtype='object')

# %% [markdown]
# ## Univariate Analysis

# %%
sns.countplot(x='Sex ', data=eda)
# Out:
# <AxesSubplot:xlabel='Sex ', ylabel='count'>

# %%
sns.countplot(x='Cabin ', data=eda)
# Out:
# <AxesSubplot:xlabel='Cabin ', ylabel='count'>

# %%
sns.countplot(x='Ticket ', data=eda)
# Out:
# <AxesSubplot:xlabel='Ticket ', ylabel='count'>

# %%
sns.countplot(x='Embarked ', data=eda)
# Out:
# <AxesSubplot:xlabel='Embarked ', ylabel='count'>

# %%
sns.boxplot(y='Age ', data=eda)
# Out:
# <AxesSubplot:ylabel='Age '>

# %%
sns.distplot(eda['Fare '], bins=4)
# Out:
# C:\Users\Enter\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Fare ', ylabel='Density'>

# %% [markdown]
# ## Bivariate Analysis

# %%
plt.scatter(eda['Age '], eda['Fare '])
plt.title('Age Vs Fare')
plt.xlabel('Age ')
plt.ylabel('Fare ')
# Out:
# Text(0, 0.5, 'Fare ')

# %%
plt.scatter(eda['Age '], eda['Survived '])
plt.title('Age Vs Survived')
plt.xlabel('Survived ')
plt.ylabel('Age ')
# Out:
# Text(0, 0.5, 'Age ')

# %%
plt.scatter(eda['Fare '], eda['Pclass '])
plt.title('Fare Vs Pclass')
plt.xlabel('Pclass ')
plt.ylabel('Fare ')
# Out:
# Text(0, 0.5, 'Fare ')

# %%
sns.heatmap(eda.corr(), annot=True, linewidth=0.5)
# Out:
# <AxesSubplot:>

# %%
eda_cont = eda.iloc[:,:-3]
eda_cont
sns.pairplot(eda_cont)

# %%
counts = eda.groupby(['Ticket ', 'Cabin '], axis= 0)
counts.size()
# Out:
# Ticket            Cabin
# 110152            B77       2
#                   B79       1
# 110413            E67       2
#                   E68       1
# 110465            A14       1
#                            ..
# S.O./P.P. 3       E77       1
# SC/AH Basle 541   D         1
# SC/Paris 2163     D         1
# W.E.P. 5734       E31       1
# WE/P 5735         B22       2
# Length: 161, dtype: int64

# %%
counts = eda.groupby(['Sex ', 'Embarked '], axis= 0)
counts.size()
# Out:
# Sex      Embarked
# female   C             73
#          Q             36
#          S            203
# male     C             95
#          Q             41
#          S            441
# dtype: int64

# %%
pd.crosstab(eda['Sex '],eda['Cabin ']).plot(kind='bar',stacked=True)
# Out:
# <AxesSubplot:xlabel='Sex '>

# %% [markdown]
#  ## Data Manipulation

# %%
eda.drop_duplicates(inplace=True)

# %%
eda.isnull()
# Out:
#       PassengerId   Survived   Pclass   Name    Sex    Age   SibSp   Parch   \
# 0            False      False    False  False  False  False   False   False
# 1             True       True     True  False   True   True    True    True
# 2            False      False    False  False  False  False   False   False
# 3             True       True     True   True   True   True    True    True
# 4            False      False    False  False  False  False   False   False
# ...            ...        ...      ...    ...    ...    ...     ...     ...
# 1137         False      False    False  False  False  False   False   False
# 1138          True       True     True  False   True   True    True    True
# 1139         False      False    False  False  False   True   False   False
# 1140         False      False    False  False  False  False   False   False
# 1141         False      False    False  False  False  False   False   False
#
#       Ticket   Fare   Cabin   Embarked
# ...

# %%
eda.isnull().sum()
# Out:
# PassengerId     214
# Survived        214
# Pclass          214
# Name             17
# Sex             214
# Age             391
# SibSp           214
# Parch           214
# Ticket          205
# Fare            214
# Cabin           882
# Embarked        216
# dtype: int64

# %%
eda.shape
# Out:
# (1105, 12)

# %%
eda['Age '].fillna(value=eda['Age '].mean(), inplace=True)

# %%
eda.loc[eda['Age '].isnull()==True].shape
# Out:
# (0, 12)

# %%
eda['Fare '].fillna(value=eda['Fare '].mean(), inplace=True)

# %%
eda.loc[eda['Fare '].isnull()==True].shape
# Out:
# (0, 12)

# %%
eda['Survived '].fillna(value=eda['Survived '].mode()[0], inplace=True)

# %%
eda['Pclass '].fillna(value=eda['Pclass '].mode()[0], inplace=True)

# %%
eda['Embarked '].fillna(value=eda['Embarked '].mode()[0], inplace=True)

# %%
eda.dropna(subset=['Sex '],inplace=True)

# %%
eda.isnull().sum()
# Out:
# PassengerId       0
# Survived          0
# Pclass            0
# Name              0
# Sex               0
# Age               0
# SibSp             0
# Parch             0
# Ticket            0
# Fare              0
# Cabin           687
# Embarked          0
# dtype: int64

# %%
eda.shape
# Out:
# (891, 12)

# %%
eda['Cabin '].fillna(value=eda['Cabin '].mode()[0], inplace=True)

# %%
eda.shape
# Out:
# (891, 12)

# %%
eda.isnull().sum()
# Out:
# PassengerId     0
# Survived        0
# Pclass          0
# Name            0
# Sex             0
# Age             0
# SibSp           0
# Parch           0
# Ticket          0
# Fare            0
# Cabin           0
# Embarked        0
# dtype: int64

# %%
eda.boxplot(column = ['Fare '])
# Out:
# <AxesSubplot:>

# %%
eda['Fare '].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare , dtype: float64

# %%
plt.scatter(eda['Fare '], eda['Age '])

# %%
IQR = eda['Fare '].quantile(0.75)-eda['Fare '].quantile(0.25)
print(IQR)
# Out:
# 23.0896

# %%
Upper_OutlierLimit = eda['Fare '].quantile(0.75) + 1.5*IQR
Lower_OutlierLimit = eda['Fare '].quantile(0.25) - 1.5*IQR
print(Upper_OutlierLimit)
print(Lower_OutlierLimit)
# Out:
# 65.6344
# -26.724

# %%
OutlierValues = eda[(eda['Fare ']>=Upper_OutlierLimit) | (eda['Fare ']<=Lower_OutlierLimit)]

# %%
 OutlierValues
# Out:
#       PassengerId   Survived   Pclass                             Name   \
# 2              2.0        1.0      1.0        (Florence Briggs Thayer)
# 39            28.0        0.0      1.0  Fortune, Mr. Charles Alexander
# 44            32.0        1.0      1.0                 (Marie Eugenie)
# 47            35.0        0.0      1.0         Meyer, Mr. Edgar Joseph
# 72            53.0        1.0      1.0                   (Myna Haxtun)
# ...            ...        ...      ...                              ...
# 1079         847.0        0.0      3.0        Sage, Mr. Douglas Bullen
# 1083         850.0        1.0      1.0              (Edwiga Grabowska)
# 1093         857.0        1.0      1.0                (Mary Hitchcock)
# 1103         864.0        0.0      3.0                         "Dolly"
# 1126         880.0        1.0      1.0                Alexenia Wilson)
#
#          Sex        Age   SibSp   Parch     Ticket      Fare  Cabin  Embarked
# ...
